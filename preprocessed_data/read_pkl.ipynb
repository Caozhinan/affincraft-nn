# %%
#!/usr/bin/env python3
import pickle
import numpy as np

INPUT_FILE = "./complex1_all_fixed.pkl"
N_ELEMS = 10   # 打印前多少个元素

def describe_value(v):
    """返回每个值的类型、形状或内容"""
    try:
        import torch
        if isinstance(v, torch.Tensor):
            return f"torch.Tensor, shape={tuple(v.shape)}, dtype={v.dtype}"
    except ImportError:
        pass

    if isinstance(v, np.ndarray):
        return f"numpy.ndarray, shape={v.shape}, dtype={v.dtype}"
    elif isinstance(v, (list, tuple)):
        return f"{type(v).__name__}, len={len(v)}"
    elif isinstance(v, dict):
        return f"dict(len={len(v)})"
    else:
        return f"{type(v).__name__}, value={str(v)[:200]}"

def main():
    with open(INPUT_FILE, "rb") as f:
        obj = pickle.load(f)   # 顶层 list
        print(f"=== 顶层对象: list, len={len(obj)} ===")
        for i, elem in enumerate(obj[:N_ELEMS]):
            print(f"\n--- 元素 {i} ---")
            if isinstance(elem, dict):
                for k, v in elem.items():
                    desc = describe_value(v)
                    print(f"  {k}: {desc}")
            else:
                print(f"  [非dict元素] {describe_value(elem)}")

    print(f"\n✅ 已打印前 {N_ELEMS} 个元素")

if __name__ == "__main__":
    main()
# Out:
# === 顶层对象: list, len=5000 ===
#
# --- 元素 0 ---
#   edge_index: numpy.ndarray, shape=(2, 1496), dtype=int64
#   edge_feat: numpy.ndarray, shape=(1496, 4), dtype=float32
#   node_feat: numpy.ndarray, shape=(130, 9), dtype=int64
#   coords: numpy.ndarray, shape=(130, 3), dtype=float64
#   pro_name: numpy.ndarray, shape=(560,), dtype=<U3
#   AA_name: numpy.ndarray, shape=(560,), dtype=<U3
#   smiles: str, value=Cc1nn(-c2ccnc(Nc3ccc4c(c3)c(C)nn4C)n2)cc1C[NH]1CC(O)C1
#   rmsd: float, value=2.506
#   gbscore: numpy.ndarray, shape=(400,), dtype=float64
#   pk: float, value=8.72
#   pdbid: str, value=4xg8_frame64
#   num_node: numpy.ndarray, shape=(2,), dtype=int64
#   num_edge: numpy.ndarray, shape=(5,), dtype=int64
#   lig_spatial_edge_index: numpy.ndarray, shape=(2, 278), dtype=int64
#   lig_spatial_edge_attr: numpy.ndarray, shape=(278, 4), dtype=float32
#   pro_spatial_edge_index: numpy.ndarray, shape=(2, 964), dtype=int64
#   pro_spatial_edge_attr: numpy.ndarray, shape=(964, 4), dtype=float32
#   masif_desc_straight: numpy.ndarray, shape=(5646, 80), dtype=float32
#
# --- 元素 1 ---
#   edge_index: numpy.ndarray, shape=(2, 2194), dtype=int64
#   edge_feat: numpy.ndarray, shape=(2194, 4), dtype=float32
#   node_feat: numpy.ndarray, shape=(174, 9), dtype=int64
#   coords: numpy.ndarray, shape=(174, 3), dtype=float64
#   pro_name: numpy.ndarray, shape=(596,), dtype=<U3
#   AA_name: numpy.ndarray, shape=(596,), dtype=<U3
#   smiles: str, value=CC(C)CCN(C[C@@H](O)[C@@H]1CC2=CC=C(C=C2)OCCCC(=O)N[C@@H](CC(N)=O)C(=O)N1)S(=O)(=O)C1=CC=CC=C1
#   rmsd: float, value=3.756
#   gbscore: numpy.ndarray, shape=(400,), dtype=float64
#   pk: float, value=9.22
#   pdbid: str, value=1z1r_frame32
#   num_node: numpy.ndarray, shape=(2,), dtype=int64
#   num_edge: numpy.ndarray, shape=(5,), dtype=int64
#   lig_spatial_edge_index: numpy.ndarray, shape=(2, 524), dtype=int64
#   lig_spatial_edge_attr: numpy.ndarray, shape=(524, 4), dtype=float32
#   pro_spatial_edge_index: numpy.ndarray, shape=(2, 1332), dtype=int64
#   pro_spatial_edge_attr: numpy.ndarray, shape=(1332, 4), dtype=float32
#   masif_desc_straight: numpy.ndarray, shape=(4094, 80), dtype=float32
#
# --- 元素 2 ---
#   edge_index: numpy.ndarray, shape=(2, 2104), dtype=int64
#   edge_feat: numpy.ndarray, shape=(2104, 4), dtype=float32
#   node_feat: numpy.ndarray, shape=(174, 9), dtype=int64
#   coords: numpy.ndarray, shape=(174, 3), dtype=float64
#   pro_name: numpy.ndarray, shape=(695,), dtype=<U3
#   AA_name: numpy.ndarray, shape=(695,), dtype=<U3
#   smiles: str, value=CC(C)CN(C[C@@H](O)[C@H](CC1=CC=CC=C1)NC(=O)O[C@H]1CCOC1)S(=O)(=O)C1=CC=C(N)C=C1
#   rmsd: float, value=1.159
#   gbscore: numpy.ndarray, shape=(400,), dtype=float64
#   pk: float, value=9.05
#   pdbid: str, value=3nu9_frame44
#   num_node: numpy.ndarray, shape=(2,), dtype=int64
#   num_edge: numpy.ndarray, shape=(5,), dtype=int64
#   lig_spatial_edge_index: numpy.ndarray, shape=(2, 382), dtype=int64
#   lig_spatial_edge_attr: numpy.ndarray, shape=(382, 4), dtype=float32
#   pro_spatial_edge_index: numpy.ndarray, shape=(2, 1390), dtype=int64
#   pro_spatial_edge_attr: numpy.ndarray, shape=(1390, 4), dtype=float32
#   masif_desc_straight: numpy.ndarray, shape=(4134, 80), dtype=float32
#
# --- 元素 3 ---
#   edge_index: numpy.ndarray, shape=(2, 2140), dtype=int64
#   edge_feat: numpy.ndarray, shape=(2140, 4), dtype=float32
#   node_feat: numpy.ndarray, shape=(176, 9), dtype=int64
#   coords: numpy.ndarray, shape=(176, 3), dtype=float64
#   pro_name: numpy.ndarray, shape=(634,), dtype=<U3
#   AA_name: numpy.ndarray, shape=(634,), dtype=<U3
#   smiles: str, value=CCCN(C(=O)N[C@@H](CSCC(C)C)C(=O)O)C(=O)C1=CC(C#CC2=CC=C(F)C=C2F)=CC=C1
#   rmsd: float, value=1.187
#   gbscore: numpy.ndarray, shape=(400,), dtype=float64
#   pk: float, value=5.68
#   pdbid: str, value=4c52_frame48
#   num_node: numpy.ndarray, shape=(2,), dtype=int64
#   num_edge: numpy.ndarray, shape=(5,), dtype=int64
#   lig_spatial_edge_index: numpy.ndarray, shape=(2, 348), dtype=int64
#   lig_spatial_edge_attr: numpy.ndarray, shape=(348, 4), dtype=float32
#   pro_spatial_edge_index: numpy.ndarray, shape=(2, 1452), dtype=int64
#   pro_spatial_edge_attr: numpy.ndarray, shape=(1452, 4), dtype=float32
#   masif_desc_straight: numpy.ndarray, shape=(6094, 80), dtype=float32
#
# --- 元素 4 ---
#   edge_index: numpy.ndarray, shape=(2, 1188), dtype=int64
#   edge_feat: numpy.ndarray, shape=(1188, 4), dtype=float32
#   node_feat: numpy.ndarray, shape=(90, 9), dtype=int64
#   coords: numpy.ndarray, shape=(90, 3), dtype=float64
#   pro_name: numpy.ndarray, shape=(535,), dtype=<U3
#   AA_name: numpy.ndarray, shape=(535,), dtype=<U3
#   smiles: str, value=NC(=[NH2])c1ccccc1
#   rmsd: float, value=2.024
#   gbscore: numpy.ndarray, shape=(400,), dtype=float64
#   pk: float, value=1.82
#   pdbid: str, value=1bra_frame44
#   num_node: numpy.ndarray, shape=(2,), dtype=int64
#   num_edge: numpy.ndarray, shape=(5,), dtype=int64
#   lig_spatial_edge_index: numpy.ndarray, shape=(2, 52), dtype=int64
#   lig_spatial_edge_attr: numpy.ndarray, shape=(52, 4), dtype=float32
#   pro_spatial_edge_index: numpy.ndarray, shape=(2, 970), dtype=int64
#   pro_spatial_edge_attr: numpy.ndarray, shape=(970, 4), dtype=float32
#   masif_desc_straight: numpy.ndarray, shape=(7926, 80), dtype=float32
#
# --- 元素 5 ---
#   edge_index: numpy.ndarray, shape=(2, 332), dtype=int64
#   edge_feat: numpy.ndarray, shape=(332, 4), dtype=float32
#   node_feat: numpy.ndarray, shape=(52, 9), dtype=int64
#   coords: numpy.ndarray, shape=(52, 3), dtype=float64
#   pro_name: numpy.ndarray, shape=(485,), dtype=<U3
#   AA_name: numpy.ndarray, shape=(485,), dtype=<U3
#   smiles: str, value=CCCCCCCC(=O)O
#   rmsd: float, value=2.388
#   gbscore: numpy.ndarray, shape=(400,), dtype=float64
#   pk: float, value=4.03
#   pdbid: str, value=3nq9_frame92
#   num_node: numpy.ndarray, shape=(2,), dtype=int64
#   num_edge: numpy.ndarray, shape=(5,), dtype=int64
#   lig_spatial_edge_index: numpy.ndarray, shape=(2, 42), dtype=int64
#   lig_spatial_edge_attr: numpy.ndarray, shape=(42, 4), dtype=float32
#   pro_spatial_edge_index: numpy.ndarray, shape=(2, 206), dtype=int64
#   pro_spatial_edge_attr: numpy.ndarray, shape=(206, 4), dtype=float32
#   masif_desc_straight: numpy.ndarray, shape=(3459, 80), dtype=float32
#
# --- 元素 6 ---
#   edge_index: numpy.ndarray, shape=(2, 2514), dtype=int64
#   edge_feat: numpy.ndarray, shape=(2514, 4), dtype=float32
#   node_feat: numpy.ndarray, shape=(183, 9), dtype=int64
#   coords: numpy.ndarray, shape=(183, 3), dtype=float64
#   pro_name: numpy.ndarray, shape=(330,), dtype=<U3
#   AA_name: numpy.ndarray, shape=(330,), dtype=<U3
#   smiles: str, value=CC(=O)N[C@H](C(=O)N1CCC[C@H]1C(=O)N1CCC[C@H]1C(=O)N1CCC[C@H]1C(=O)N[C@H](C(=O)N1CCC[C@H]1C(=O)N1CCC[C@H]1C(=O)N[C@@H](CCCNC(N)=[NH2])C(=O)N[C@@H](CCCNC(N)=[NH2])C(=O)N[C@@H](CCCNC(N)=[NH2])C(N)=O)C(C)
#   rmsd: float, value=3.666
#   gbscore: numpy.ndarray, shape=(400,), dtype=float64
#   pk: float, value=5.46
#   pdbid: str, value=3gbq_frame48
#   num_node: numpy.ndarray, shape=(2,), dtype=int64
#   num_edge: numpy.ndarray, shape=(5,), dtype=int64
#   lig_spatial_edge_index: numpy.ndarray, shape=(2, 1010), dtype=int64
#   lig_spatial_edge_attr: numpy.ndarray, shape=(1010, 4), dtype=float32
#   pro_spatial_edge_index: numpy.ndarray, shape=(2, 1122), dtype=int64
#   pro_spatial_edge_attr: numpy.ndarray, shape=(1122, 4), dtype=float32
#   masif_desc_straight: numpy.ndarray, shape=(1726, 80), dtype=float32
#
# --- 元素 7 ---
#   edge_index: numpy.ndarray, shape=(2, 1752), dtype=int64
#   edge_feat: numpy.ndarray, shape=(1752, 4), dtype=float32
#   node_feat: numpy.ndarray, shape=(130, 9), dtype=int64
#   coords: numpy.ndarray, shape=(130, 3), dtype=float64
#   pro_name: numpy.ndarray, shape=(669,), dtype=<U3
#   AA_name: numpy.ndarray, shape=(669,), dtype=<U3
#   smiles: str, value=O=C1NC(=O)C(N(=O)=O)=C(NC[C@H](O)[C@H](O)[C@H](O)CO)N1
#   rmsd: float, value=1.59
#   gbscore: numpy.ndarray, shape=(400,), dtype=float64
#   pk: float, value=7.38
#   pdbid: str, value=1t13_frame12
#   num_node: numpy.ndarray, shape=(2,), dtype=int64
#   num_edge: numpy.ndarray, shape=(5,), dtype=int64
#   lig_spatial_edge_index: numpy.ndarray, shape=(2, 206), dtype=int64
#   lig_spatial_edge_attr: numpy.ndarray, shape=(206, 4), dtype=float32
#   pro_spatial_edge_index: numpy.ndarray, shape=(2, 1284), dtype=int64
#   pro_spatial_edge_attr: numpy.ndarray, shape=(1284, 4), dtype=float32
#   masif_desc_straight: numpy.ndarray, shape=(23802, 80), dtype=float32
#
# --- 元素 8 ---
#   edge_index: numpy.ndarray, shape=(2, 1192), dtype=int64
#   edge_feat: numpy.ndarray, shape=(1192, 4), dtype=float32
#   node_feat: numpy.ndarray, shape=(103, 9), dtype=int64
#   coords: numpy.ndarray, shape=(103, 3), dtype=float64
#   pro_name: numpy.ndarray, shape=(515,), dtype=<U3
#   AA_name: numpy.ndarray, shape=(515,), dtype=<U3
#   smiles: str, value=C[C@H](CC(=O)O)C1=NN(C)C2=C(C(=O)N[C@@H](N)N2)C1=O
#   rmsd: float, value=1.139
#   gbscore: numpy.ndarray, shape=(400,), dtype=float64
#   pk: float, value=3.84
#   pdbid: str, value=4d9p_frame68
#   num_node: numpy.ndarray, shape=(2,), dtype=int64
#   num_edge: numpy.ndarray, shape=(5,), dtype=int64
#   lig_spatial_edge_index: numpy.ndarray, shape=(2, 238), dtype=int64
#   lig_spatial_edge_attr: numpy.ndarray, shape=(238, 4), dtype=float32
#   pro_spatial_edge_index: numpy.ndarray, shape=(2, 770), dtype=int64
#   pro_spatial_edge_attr: numpy.ndarray, shape=(770, 4), dtype=float32
#   masif_desc_straight: numpy.ndarray, shape=(9526, 80), dtype=float32
#
# --- 元素 9 ---
#   edge_index: numpy.ndarray, shape=(2, 1714), dtype=int64
#   edge_feat: numpy.ndarray, shape=(1714, 4), dtype=float32
#   node_feat: numpy.ndarray, shape=(142, 9), dtype=int64
#   coords: numpy.ndarray, shape=(142, 3), dtype=float64
#   pro_name: numpy.ndarray, shape=(564,), dtype=<U3
#   AA_name: numpy.ndarray, shape=(564,), dtype=<U3
#   smiles: str, value=CC1=C/C2=C(\C=C/1)[C@]1(CC2)COC2=C(C=C(C(=O)O)C=C2)N(CC2CCC2)C1
#   rmsd: float, value=0.983
#   gbscore: numpy.ndarray, shape=(400,), dtype=float64
#   pk: float, value=10.4
#   pdbid: str, value=6o6f_frame60
#   num_node: numpy.ndarray, shape=(2,), dtype=int64
#   num_edge: numpy.ndarray, shape=(5,), dtype=int64
#   lig_spatial_edge_index: numpy.ndarray, shape=(2, 314), dtype=int64
#   lig_spatial_edge_attr: numpy.ndarray, shape=(314, 4), dtype=float32
#   pro_spatial_edge_index: numpy.ndarray, shape=(2, 1112), dtype=int64
#   pro_spatial_edge_attr: numpy.ndarray, shape=(1112, 4), dtype=float32
#   masif_desc_straight: numpy.ndarray, shape=(3368, 80), dtype=float32
#
# ✅ 已打印前 10 个元素

# %%
#!/usr/bin/env python3
import pickle

INPUT_FILE = "./complex1_all_fixed.pkl"

def main():
    with open(INPUT_FILE, "rb") as f:
        obj = pickle.load(f)

    if isinstance(obj, list):
        print(f"顶层对象是 list, len={len(obj)}")

        # 统计元素的类型数量
        counts = {}
        for elem in obj:
            t = type(elem).__name__
            counts[t] = counts.get(t, 0) + 1

        print("元素类型分布：")
        for k, v in counts.items():
            print(f"  {k}: {v}")
    else:
        print(f"顶层对象类型: {type(obj).__name__}")

if __name__ == "__main__":
    main()
# Out:
# 顶层对象是 list, len=5000
# 元素类型分布：
#   dict: 5000

# %%
#!/usr/bin/env python3
import pickle
import numpy as np

INPUT_FILE = "/xcfhome/zncao02/affincraft-nn/preprocessed_data/sample20.pkl"
N_ELEMS = 10     # 总共打印前多少个元素
DETAIL_ELEMS = 2 # 前多少个元素打印具体数值

def describe_value(v, show_value=False):
    """返回可读的描述字符串，show_value=True 时打印具体内容"""
    try:
        import torch
        if isinstance(v, torch.Tensor):
            if show_value:
                return f"torch.Tensor, shape={tuple(v.shape)}, dtype={v.dtype}, value={v}"
            else:
                return f"torch.Tensor, shape={tuple(v.shape)}, dtype={v.dtype}"
    except ImportError:
        pass

    if isinstance(v, np.ndarray):
        if show_value:
            return f"numpy.ndarray, shape={v.shape}, dtype={v.dtype}, value=\n{v}"
        else:
            return f"numpy.ndarray, shape={v.shape}, dtype={v.dtype}"
    elif isinstance(v, (list, tuple)):
        if show_value:
            return f"{type(v).__name__}, len={len(v)}, value={v}"
        else:
            return f"{type(v).__name__}, len={len(v)}"
    elif isinstance(v, dict):
        return f"dict(len={len(v)})"
    else:
        return f"{type(v).__name__}, value={v}"

def main():
    with open(INPUT_FILE, "rb") as f:
        obj = pickle.load(f)   # 顶层 list
        print(f"=== 顶层对象: list, len={len(obj)} ===")
        for i, elem in enumerate(obj[:N_ELEMS]):
            print(f"\n--- 元素 {i} ---")
            if isinstance(elem, dict):
                for k, v in elem.items():
                    desc = describe_value(v, show_value=(i < DETAIL_ELEMS))
                    print(f"  {k}: {desc}")
            else:
                desc = describe_value(elem, show_value=(i < DETAIL_ELEMS))
                print(f"  [非dict元素] {desc}")

    print(f"\n✅ 已打印前 {N_ELEMS} 个元素（前 {DETAIL_ELEMS} 个包含具体值）")

if __name__ == "__main__":
    main()
# Out:
# === 顶层对象: list, len=18 ===
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 53
#      50     print(f"\n✅ 已打印前 {N_ELEMS} 个元素（前 {DETAIL_ELEMS} 个包含具体值）")
#      52 if __name__ == "__main__":
# ---> 53     main()
#
# Cell In[3], line 40, in main()
#      38 obj = pickle.load(f)   # 顶层 list
#      39 print(f"=== 顶层对象: list, len={len(obj)} ===")
# ---> 40 for i, elem in enumerate(obj[:N_ELEMS]):
#      41     print(f"\n--- 元素 {i} ---")
#      42     if isinstance(elem, dict):
#
# TypeError: unhashable type: 'slice'

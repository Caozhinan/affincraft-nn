# %%
zncao02@f101$ bash '/xcfhome/zncao02/affincraft-nn/graphormer/train_finetune/md_multi_gpu.sh' ~/pkl_affincraft/train.pkl ~/pkl_affincraft/valid.pkl 
======================================================
开始4卡分布式预训练 AffinCraft 模型...
======================================================
硬件配置: 1x NVIDIA A100-SXM4-40GB
训练数据: /xcfhome/zncao02/pkl_affincraft/train.pkl
验证数据: /xcfhome/zncao02/pkl_affincraft/valid.pkl
检查点保存到: ./affincraft_pretrain_ckpts
------------------------------------------------------
/xcfhome/zncao02/anaconda3/envs/dynaformer/bin/python: can't open file '/xcfhome/zncao02/affincraft-nn/graphormer/ ': [Errno 2] No such file or directory
E0919 16:11:51.971151 2287743 torch/distributed/elastic/multiprocessing/api.py:869] failed (exitcode: 2) local_rank: 0 (pid: 2287766) of binary: /xcfhome/zncao02/anaconda3/envs/dynaformer/bin/python
Traceback (most recent call last):
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/bin/torchrun", line 8, in <module>
    sys.exit(main())
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/torch/distributed/elastic/multiprocessing/errors/__init__.py", line 355, in wrapper
    return f(*args, **kwargs)
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/torch/distributed/run.py", line 918, in main
    run(args)
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/torch/distributed/run.py", line 909, in run
    elastic_launch(
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/torch/distributed/launcher/api.py", line 138, in __call__
    return launch_agent(self._config, self._entrypoint, list(args))
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/torch/distributed/launcher/api.py", line 269, in launch_agent
    raise ChildFailedError(
torch.distributed.elastic.multiprocessing.errors.ChildFailedError: 
============================================================
  FAILED
------------------------------------------------------------
Failures:
  <NO_OTHER_FAILURES>
------------------------------------------------------------
Root Cause (first observed failure):
[0]:
  time      : 2025-09-19_16:11:51
  host      : f101.hn.org
  rank      : 0 (local_rank: 0)
  exitcode  : 2 (pid: 2287766)
  error_file: <N/A>
  traceback : To enable traceback see: https://pytorch.org/docs/stable/elastic/errors.html
============================================================

# %%
报错：zncao02@f134$ bash graphormer/train_finetune/md_train.sh ~/pkl_affincraft/train.pkl ~/pkl_affincraft/valid.pkl
2025-09-20 16:22:44 | INFO | fairseq_cli.train | GraphormerModel(
  (encoder): GraphormerEncoder(
    (graph_encoder): AffinCraftGraphEncoder(
      (dropout_module): FairseqDropout()
      (graph_node_feature): AffinCraftNodeFeature(
        (node_encoder): Linear(in_features=9, out_features=1024, bias=True)
        (graph_token): Embedding(1, 1024)
        (masif_encoder): Sequential(
          (0): Linear(in_features=80, out_features=1024, bias=True)
          (1): GELU(approximate='none')
          (2): Linear(in_features=1024, out_features=1024, bias=True)
        )
        (gbscore_encoder): Sequential(
          (0): Linear(in_features=400, out_features=1024, bias=True)
          (1): GELU(approximate='none')
          (2): Linear(in_features=1024, out_features=1024, bias=True)
        )
        (feature_fusion): Linear(in_features=3072, out_features=1024, bias=True)
      )
      (graph_attn_bias): AffinCraftAttnBias(
        (structural_edge_encoder): Embedding(20, 16, padding_idx=0)
        (plip_intra_protein_encoder): Embedding(15, 16, padding_idx=0)
        (plip_intra_ligand_encoder): Embedding(15, 16, padding_idx=0)
        (plip_inter_molecular_encoder): Embedding(15, 16, padding_idx=0)
        (distance_encoder): Sequential(
          (0): Linear(in_features=1, out_features=16, bias=True)
          (1): ReLU()
          (2): Linear(in_features=16, out_features=16, bias=True)
        )
        (edge_location_encoder): Embedding(4, 16)
        (graph_token_virtual_distance): Embedding(1, 16)
        (angle_encoder): Sequential(
          (0): Linear(in_features=28, out_features=16, bias=True)
          (1): ReLU()
          (2): Linear(in_features=16, out_features=16, bias=True)
        )
        (multi_dist_encoder): Sequential(
          (0): Linear(in_features=28, out_features=16, bias=True)
          (1): ReLU()
          (2): Linear(in_features=16, out_features=16, bias=True)
        )
      )
      (emb_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
      (layers): ModuleList(
        (0-23): 24 x GraphormerGraphEncoderLayer(
          (dropout_module): FairseqDropout()
          (activation_dropout_module): FairseqDropout()
          (self_attn): MultiheadAttention(
            (dropout_module): FairseqDropout()
            (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
            (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
            (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
            (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
          )
          (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
          (fc1): Linear(in_features=1024, out_features=1024, bias=True)
          (fc2): Linear(in_features=1024, out_features=1024, bias=True)
          (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
        )
      )
    )
    (masked_lm_pooler): Linear(in_features=1024, out_features=1024, bias=True)
    (lm_head_transform_weight): Linear(in_features=1024, out_features=1024, bias=True)
    (layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
    (embed_out): Linear(in_features=1024, out_features=1, bias=False)
  )
)
2025-09-20 16:22:44 | INFO | fairseq_cli.train | task: GraphPredictionTask
2025-09-20 16:22:44 | INFO | fairseq_cli.train | model: GraphormerModel
2025-09-20 16:22:44 | INFO | fairseq_cli.train | criterion: GraphPredictionL2LossWithRMSDAndFlag
2025-09-20 16:22:44 | INFO | fairseq_cli.train | num. shared model params: 159,098,705 (num. trained: 159,098,705)
2025-09-20 16:22:44 | INFO | fairseq_cli.train | num. expert model params: 0 (num. trained: 0)
[rank0]:[W920 16:22:45.310366325 ProcessGroupNCCL.cpp:1496] Warning: WARNING: destroy_process_group() was not called before program exit, which can leak resources. For more info, please see https://pytorch.org/docs/stable/distributed.html#shutdown (function operator())
W0920 16:22:46.633426 634441 torch/multiprocessing/spawn.py:169] Terminating process 634466 via signal SIGTERM
Traceback (most recent call last):
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/bin/fairseq-train", line 8, in <module>
    sys.exit(cli_main())
  File "/xcfhome/zncao02/model_bap/Dynafomer/Dynaformer/fairseq/fairseq_cli/train.py", line 529, in cli_main
    distributed_utils.call_main(cfg, main)
  File "/xcfhome/zncao02/model_bap/Dynafomer/Dynaformer/fairseq/fairseq/distributed/utils.py", line 344, in call_main
    torch.multiprocessing.spawn(
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 340, in spawn
    return start_processes(fn, args, nprocs, join, daemon, start_method="spawn")
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 296, in start_processes
    while not context.join():
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 215, in join
    raise ProcessRaisedException(msg, error_index, failed_process.pid)
torch.multiprocessing.spawn.ProcessRaisedException: 

-- Process 0 terminated with the following error:
Traceback (most recent call last):
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 90, in _wrap
    fn(i, *args)
  File "/xcfhome/zncao02/model_bap/Dynafomer/Dynaformer/fairseq/fairseq/distributed/utils.py", line 328, in distributed_main
    main(cfg, **kwargs)
  File "/xcfhome/zncao02/model_bap/Dynafomer/Dynaformer/fairseq/fairseq_cli/train.py", line 131, in main
    task.load_dataset(valid_sub_split, combine=False, epoch=1)
  File "/xcfhome/zncao02/affincraft-nn/graphormer/tasks/graph_prediction.py", line 383, in load_dataset
    dataset = NestedDictionaryDataset(
  File "/xcfhome/zncao02/model_bap/Dynafomer/Dynaformer/fairseq/fairseq/data/nested_dictionary_dataset.py", line 62, in __init__
    raise ValueError("Expected Dataset but found: {}".format(v.__class__))
ValueError: Expected Dataset but found: <class 'graphormer.tasks.graph_prediction.AffinCraftTargetDataset'>

======================================================
单卡预训练完成。检查点已保存到: ./affincraft_pretrain_ckpts
======================================================
